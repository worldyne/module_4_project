# %%
import os
import tensorflow as tf
assert 'COLAB_TPU_ADDR' in os.environ, 'ERROR: Not connected to a TPU runtime; please see the first cell in this notebook for instructions!'
TPU_ADDRESS = 'grpc://' + os.environ['COLAB_TPU_ADDR']
print('TPU address is', TPU_ADDRESS)

from google.colab import auth
auth.authenticate_user()
# Out:
# TPU address is grpc://10.35.58.234:8470
# WARNING: Logging before flag parsing goes to stderr.
# W0620 14:04:00.642498 139746805892992 lazy_loader.py:50]
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
#from google.colab import drive
#drive.mount('/content/gdrive')
from google.cloud import storage
client = storage.Client('My First Project')
# https://console.cloud.google.com/storage/browser/[bucket-id]/
bucket = client.get_bucket('module-4-project')

# !gsutil cp -r gs://module-4-project/BERT_keras/ /tmp/
# !gsutil cp gs://module-4-project/marvel_bios.json /tmp/
os.chdir('../tmp/')
# Out:
# W0620 14:04:01.807059 139746805892992 _default.py:280] No project ID could be determined. Consider running `gcloud config set project` or setting the GOOGLE_CLOUD_PROJECT environment variable
# Copying gs://module-4-project/BERT_keras/.DS_Store...
# Copying gs://module-4-project/BERT_keras/.git...
# Copying gs://module-4-project/BERT_keras/.gitignore...
# Copying gs://module-4-project/BERT_keras/.gitmodules...
# / [4 files][ 11.4 KiB/ 11.4 KiB]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# Copying gs://module-4-project/BERT_keras/.ipynb_checkpoints/tutorial-checkpoint.ipynb...
# Copying gs://module-4-project/BERT_keras/LICENSE...
# Copying gs://module-4-project/BERT_keras/README.md...
# Copying gs://module-4-project/BERT_keras/__init__.py...
# Copying gs://module-4-project/BERT_keras/__pycache__/__init__.cpython-36.pyc...
# Copying gs://module-4-project/BERT_keras/__pycache__/__init__.cpython-37.pyc...
# Copying gs://module-4-project/BERT_keras/data/__pycache__/vocab.cpython-36.pyc...
# Copying gs://module-4-project/BERT_keras/data/__pycache__/vocab.cpython-37.pyc...
# Copying gs://module-4-project/BERT_keras/data/dataset.py...
# Copying gs://module-4-project/BERT_keras/data/lm_dataset.py...
# Copying gs://module-4-project/BERT_keras/data/vocab.py...
# Copying gs://module-4-project/BERT_keras/google_bert/.DS_Store...
# Copying gs://module-4-project/BERT_keras/google_bert/.git...
# Copying gs://module-4-project/BERT_keras/google_bert/.gitignore...
# Copying gs://module-4-project/BERT_keras/google_bert/CONTRIBUTING.md...
# Copying gs://module-4-project/BERT_keras/google_bert/LICENSE...
# Copying gs://module-4-project/BERT_keras/google_bert/README.md...
# Copying gs://module-4-project/BERT_keras/google_bert/__init__.py...
# Copying gs://module-4-project/BERT_keras/google_bert/__pycache__/__init__.cpython-36.pyc...
# Copying gs://module-4-project/BERT_keras/google_bert/__pycache__/__init__.cpython-37.pyc...
# Copying gs://module-4-project/BERT_keras/google_bert/__pycache__/extract_features.cpython-36.pyc...
# Copying gs://module-4-project/BERT_keras/google_bert/__pycache__/extract_features.cpython-37.pyc...
# Copying gs://module-4-project/BERT_keras/google_bert/__pycache__/modeling.cpython-36.pyc...
# Copying gs://module-4-project/BERT_keras/google_bert/__pycache__/modeling.cpython-37.pyc...
# Copying gs://module-4-project/BERT_keras/google_bert/__pycache__/tokenization.cpython-36.pyc...
# Copying gs://module-4-project/BERT_keras/google_bert/__pycache__/tokenization.cpython-37.pyc...
# Copying gs://module-4-project/BERT_keras/google_bert/create_pretraining_data.py...
# Copying gs://module-4-project/BERT_keras/google_bert/extract_features.py...
# Copying gs://module-4-project/BERT_keras/google_bert/modeling.py...
# Copying gs://module-4-project/BERT_keras/google_bert/modeling_test.py...
# Copying gs://module-4-project/BERT_keras/google_bert/multilingual.md...
# Copying gs://module-4-project/BERT_keras/google_bert/optimization.py...
# Copying gs://module-4-project/BERT_keras/google_bert/optimization_test.py...
# Copying gs://module-4-project/BERT_keras/google_bert/predicting_movie_reviews_with_bert_on_tf_hub.ipynb...
# Copying gs://module-4-project/BERT_keras/google_bert/requirements.txt...
# Copying gs://module-4-project/BERT_keras/google_bert/run_classifier.py...
# Copying gs://module-4-project/BERT_keras/google_bert/run_classifier_with_tfhub.py...
# Copying gs://module-4-project/BERT_keras/google_bert/run_pretraining.py...
# Copying gs://module-4-project/BERT_keras/google_bert/run_squad.py...
# Copying gs://module-4-project/BERT_keras/google_bert/sample_text.txt...
# Copying gs://module-4-project/BERT_keras/google_bert/tokenization.py...
# Copying gs://module-4-project/BERT_keras/google_bert/tokenization_test.py...
# Copying gs://module-4-project/BERT_keras/tests/__init__.py...
# Copying gs://module-4-project/BERT_keras/tests/test_bert.py...
# Copying gs://module-4-project/BERT_keras/tests/test_data.py...
# Copying gs://module-4-project/BERT_keras/tests/test_transformer.py...
# Copying gs://module-4-project/BERT_keras/transformer/__init__.py...
# Copying gs://module-4-project/BERT_keras/transformer/__pycache__/__init__.cpython-36.pyc...
# Copying gs://module-4-project/BERT_keras/transformer/__pycache__/__init__.cpython-37.pyc...
# Copying gs://module-4-project/BERT_keras/transformer/__pycache__/embedding.cpython-36.pyc...
# Copying gs://module-4-project/BERT_keras/transformer/__pycache__/embedding.cpython-37.pyc...
# Copying gs://module-4-project/BERT_keras/transformer/__pycache__/funcs.cpython-36.pyc...
# Copying gs://module-4-project/BERT_keras/transformer/__pycache__/funcs.cpython-37.pyc...
# Copying gs://module-4-project/BERT_keras/transformer/__pycache__/layers.cpython-36.pyc...
# Copying gs://module-4-project/BERT_keras/transformer/__pycache__/layers.cpython-37.pyc...
# Copying gs://module-4-project/BERT_keras/transformer/__pycache__/load.cpython-36.pyc...
# Copying gs://module-4-project/BERT_keras/transformer/__pycache__/load.cpython-37.pyc...
# Copying gs://module-4-project/BERT_keras/transformer/__pycache__/model.cpython-36.pyc...
# Copying gs://module-4-project/BERT_keras/transformer/__pycache__/model.cpython-37.pyc...
# Copying gs://module-4-project/BERT_keras/transformer/__pycache__/train.cpython-37.pyc...
# Copying gs://module-4-project/BERT_keras/transformer/embedding.py...
# Copying gs://module-4-project/BERT_keras/transformer/funcs.py...
# Copying gs://module-4-project/BERT_keras/transformer/layers.py...
# Copying gs://module-4-project/BERT_keras/transformer/load.py...
# Copying gs://module-4-project/BERT_keras/transformer/model.py...
# Copying gs://module-4-project/BERT_keras/transformer/train.py...
# Copying gs://module-4-project/BERT_keras/tutorial.ipynb...
# Copying gs://module-4-project/BERT_keras/wwm_cased_L-24_H-1024_A-16/bert_config.json...
# Copying gs://module-4-project/BERT_keras/wwm_cased_L-24_H-1024_A-16/bert_model.ckpt.data-00000-of-00001...
# Copying gs://module-4-project/BERT_keras/wwm_cased_L-24_H-1024_A-16/bert_model.ckpt.index...
# Copying gs://module-4-project/BERT_keras/wwm_cased_L-24_H-1024_A-16/bert_model.ckpt.meta...
# Copying gs://module-4-project/BERT_keras/wwm_cased_L-24_H-1024_A-16/vocab.txt...
# | [76 files][  1.3 GiB/  1.3 GiB]   82.6 MiB/s
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
#
# Operation completed over 76 objects/1.3 GiB.
# Copying gs://module-4-project/marvel_bios.json...
# / [1 files][  9.9 MiB/  9.9 MiB]
# Operation completed over 1 objects/9.9 MiB.

# %%
import tensorflow as tf
keras = tf.keras

from BERT_keras.transformer.load import load_google_bert

from BERT_keras.google_bert.tokenization import FullTokenizer
from BERT_keras.google_bert.extract_features import convert_examples_to_features, input_fn_builder, get_features


import pandas as pd
import numpy as np
# Out:
# Using TensorFlow backend.
# W0620 14:04:28.895372 139746805892992 _default.py:280] No project ID could be determined. Consider running `gcloud config set project` or setting the GOOGLE_CLOUD_PROJECT environment variable
# if you want sentencepiece encoder, please install sentencepiece
# if you want to use OpenAI's encoder and pretrained model, please install spacy, and ftfy
# if you want to use Google's encoder and pretrained models, please clone the bert submodule

# %%
marvel = pd.read_json('marvel_bios.json')
marvel
marvel = marvel[~marvel.duplicated('bio')]

# %%
import random

# %%
marvel = marvel.sample(300)

# %%
tokener = FullTokenizer('./BERT_keras/wwm_cased_L-24_H-1024_A-16/vocab.txt')
# Out:
# W0620 14:04:29.374372 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/tokenization.py:125: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.

# %%
bert_model = load_google_bert('BERT_keras/wwm_cased_L-24_H-1024_A-16/')
# Out:
# W0620 14:04:29.542690 139746805892992 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/initializers.py:119: calling RandomUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0620 14:04:29.770418 139746805892992 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0620 14:04:30.928745 139746805892992 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/autograph/converters/directives.py:117: The name tf.erf is deprecated. Please use tf.math.erf instead.

# %%
bert_model.trainable=False

# %%
bert_model.build(None)
bert_model._layers.pop()
bert_model.summary()
# Out:
# Model: "Transformer"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# segment_input (InputLayer)      [(None, 512)]        0
# __________________________________________________________________________________________________
# position_input (InputLayer)     [(None, 512)]        0
# __________________________________________________________________________________________________
# token_input (InputLayer)        [(None, 512)]        0
# __________________________________________________________________________________________________
# SegmentEmbedding (Embedding)    (None, 512, 1024)    2048        segment_input[0][0]
# __________________________________________________________________________________________________
# PositionEmbedding (Embedding)   (None, 512, 1024)    524288      position_input[0][0]
# __________________________________________________________________________________________________
# TokenEmbedding (Embedding)      (None, 512, 1024)    29591552    token_input[0][0]
# __________________________________________________________________________________________________
# AddEmbeddings (Add)             (None, 512, 1024)    0           SegmentEmbedding[0][0]
#                                                                  PositionEmbedding[0][0]
#                                                                  TokenEmbedding[0][0]
# __________________________________________________________________________________________________
# layer_normalization (LayerNorma (None, 512, 1024)    2048        AddEmbeddings[0][0]
# __________________________________________________________________________________________________
# EmbeddingDropOut (Dropout)      (None, 512, 1024)    0           layer_normalization[0][0]
# __________________________________________________________________________________________________
# layer_0/c_attn (Conv1D)         (None, 512, 3072)    3148800     EmbeddingDropOut[0][0]
# __________________________________________________________________________________________________
# attention_mask_input (InputLaye [(None, 1, 512, 512) 0
# __________________________________________________________________________________________________
# layer_0/self_attention (MultiHe (None, 512, 1024)    0           layer_0/c_attn[0][0]
#                                                                  attention_mask_input[0][0]
# __________________________________________________________________________________________________
# layer_0/c_attn_proj (Conv1D)    (None, 512, 1024)    1049600     layer_0/self_attention[0][0]
# __________________________________________________________________________________________________
# layer_0/ln_1_drop (Dropout)     (None, 512, 1024)    0           layer_0/c_attn_proj[0][0]
# __________________________________________________________________________________________________
# layer_0/ln_1_add (Add)          (None, 512, 1024)    0           EmbeddingDropOut[0][0]
#                                                                  layer_0/ln_1_drop[0][0]
# __________________________________________________________________________________________________
# layer_0/ln_1 (LayerNormalizatio (None, 512, 1024)    2048        layer_0/ln_1_add[0][0]
# __________________________________________________________________________________________________
# layer_0/c_fc (Conv1D)           (None, 512, 4096)    4198400     layer_0/ln_1[0][0]
# __________________________________________________________________________________________________
# layer_0/gelu (Gelu)             (None, 512, 4096)    0           layer_0/c_fc[0][0]
# __________________________________________________________________________________________________
# layer_0/c_ffn_proj (Conv1D)     (None, 512, 1024)    4195328     layer_0/gelu[0][0]
# __________________________________________________________________________________________________
# layer_0/ln_2_drop (Dropout)     (None, 512, 1024)    0           layer_0/c_ffn_proj[0][0]
# __________________________________________________________________________________________________
# layer_0/ln_2_add (Add)          (None, 512, 1024)    0           layer_0/ln_1[0][0]
#                                                                  layer_0/ln_2_drop[0][0]
# __________________________________________________________________________________________________
# layer_0/ln_2 (LayerNormalizatio (None, 512, 1024)    2048        layer_0/ln_2_add[0][0]
# __________________________________________________________________________________________________
# layer_1/c_attn (Conv1D)         (None, 512, 3072)    3148800     layer_0/ln_2[0][0]
# __________________________________________________________________________________________________
# layer_1/self_attention (MultiHe (None, 512, 1024)    0           layer_1/c_attn[0][0]
#                                                                  attention_mask_input[0][0]
# __________________________________________________________________________________________________
# layer_1/c_attn_proj (Conv1D)    (None, 512, 1024)    1049600     layer_1/self_attention[0][0]
# __________________________________________________________________________________________________
# layer_1/ln_1_drop (Dropout)     (None, 512, 1024)    0           layer_1/c_attn_proj[0][0]
# __________________________________________________________________________________________________
# layer_1/ln_1_add (Add)          (None, 512, 1024)    0           layer_0/ln_2[0][0]
#                                                                  layer_1/ln_1_drop[0][0]
# __________________________________________________________________________________________________
# layer_1/ln_1 (LayerNormalizatio (None, 512, 1024)    2048        layer_1/ln_1_add[0][0]
# __________________________________________________________________________________________________
# layer_1/c_fc (Conv1D)           (None, 512, 4096)    4198400     layer_1/ln_1[0][0]
# __________________________________________________________________________________________________
# layer_1/gelu (Gelu)             (None, 512, 4096)    0           layer_1/c_fc[0][0]
# __________________________________________________________________________________________________
# layer_1/c_ffn_proj (Conv1D)     (None, 512, 1024)    4195328     layer_1/gelu[0][0]
# __________________________________________________________________________________________________
# layer_1/ln_2_drop (Dropout)     (None, 512, 1024)    0           layer_1/c_ffn_proj[0][0]
# __________________________________________________________________________________________________
# layer_1/ln_2_add (Add)          (None, 512, 1024)    0           layer_1/ln_1[0][0]
#                                                                  layer_1/ln_2_drop[0][0]
# __________________________________________________________________________________________________
# layer_1/ln_2 (LayerNormalizatio (None, 512, 1024)    2048        layer_1/ln_2_add[0][0]
# __________________________________________________________________________________________________
# layer_2/c_attn (Conv1D)         (None, 512, 3072)    3148800     layer_1/ln_2[0][0]
# __________________________________________________________________________________________________
# layer_2/self_attention (MultiHe (None, 512, 1024)    0           layer_2/c_attn[0][0]
#                                                                  attention_mask_input[0][0]
# __________________________________________________________________________________________________
# layer_2/c_attn_proj (Conv1D)    (None, 512, 1024)    1049600     layer_2/self_attention[0][0]
# __________________________________________________________________________________________________
# layer_2/ln_1_drop (Dropout)     (None, 512, 1024)    0           layer_2/c_attn_proj[0][0]
# __________________________________________________________________________________________________
# layer_2/ln_1_add (Add)          (None, 512, 1024)    0           layer_1/ln_2[0][0]
#                                                                  layer_2/ln_1_drop[0][0]
# __________________________________________________________________________________________________
# layer_2/ln_1 (LayerNormalizatio (None, 512, 1024)    2048        layer_2/ln_1_add[0][0]
# __________________________________________________________________________________________________
# layer_2/c_fc (Conv1D)           (None, 512, 4096)    4198400     layer_2/ln_1[0][0]
# __________________________________________________________________________________________________
# layer_2/gelu (Gelu)             (None, 512, 4096)    0           layer_2/c_fc[0][0]
# __________________________________________________________________________________________________
# layer_2/c_ffn_proj (Conv1D)     (None, 512, 1024)    4195328     layer_2/gelu[0][0]
# __________________________________________________________________________________________________
# layer_2/ln_2_drop (Dropout)     (None, 512, 1024)    0           layer_2/c_ffn_proj[0][0]
# __________________________________________________________________________________________________
# layer_2/ln_2_add (Add)          (None, 512, 1024)    0           layer_2/ln_1[0][0]
#                                                                  layer_2/ln_2_drop[0][0]
# __________________________________________________________________________________________________
# layer_2/ln_2 (LayerNormalizatio (None, 512, 1024)    2048        layer_2/ln_2_add[0][0]
# __________________________________________________________________________________________________
# layer_3/c_attn (Conv1D)         (None, 512, 3072)    3148800     layer_2/ln_2[0][0]
# __________________________________________________________________________________________________
# layer_3/self_attention (MultiHe (None, 512, 1024)    0           layer_3/c_attn[0][0]
#                                                                  attention_mask_input[0][0]
# __________________________________________________________________________________________________
# layer_3/c_attn_proj (Conv1D)    (None, 512, 1024)    1049600     layer_3/self_attention[0][0]
# __________________________________________________________________________________________________
# layer_3/ln_1_drop (Dropout)     (None, 512, 1024)    0           layer_3/c_attn_proj[0][0]
# __________________________________________________________________________________________________
# layer_3/ln_1_add (Add)          (None, 512, 1024)    0           layer_2/ln_2[0][0]
#                                                                  layer_3/ln_1_drop[0][0]
# __________________________________________________________________________________________________
# layer_3/ln_1 (LayerNormalizatio (None, 512, 1024)    2048        layer_3/ln_1_add[0][0]
# __________________________________________________________________________________________________
# layer_3/c_fc (Conv1D)           (None, 512, 4096)    4198400     layer_3/ln_1[0][0]
# __________________________________________________________________________________________________
# layer_3/gelu (Gelu)             (None, 512, 4096)    0           layer_3/c_fc[0][0]
# __________________________________________________________________________________________________
# layer_3/c_ffn_proj (Conv1D)     (None, 512, 1024)    4195328     layer_3/gelu[0][0]
# __________________________________________________________________________________________________
# layer_3/ln_2_drop (Dropout)     (None, 512, 1024)    0           layer_3/c_ffn_proj[0][0]
# __________________________________________________________________________________________________
# layer_3/ln_2_add (Add)          (None, 512, 1024)    0           layer_3/ln_1[0][0]
#                                                                  layer_3/ln_2_drop[0][0]
# __________________________________________________________________________________________________
# layer_3/ln_2 (LayerNormalizatio (None, 512, 1024)    2048        layer_3/ln_2_add[0][0]
# __________________________________________________________________________________________________
# layer_4/c_attn (Conv1D)         (None, 512, 3072)    3148800     layer_3/ln_2[0][0]
# __________________________________________________________________________________________________
# layer_4/self_attention (MultiHe (None, 512, 1024)    0           layer_4/c_attn[0][0]
#                                                                  attention_mask_input[0][0]
# __________________________________________________________________________________________________
# layer_4/c_attn_proj (Conv1D)    (None, 512, 1024)    1049600     layer_4/self_attention[0][0]
# __________________________________________________________________________________________________
# layer_4/ln_1_drop (Dropout)     (None, 512, 1024)    0           layer_4/c_attn_proj[0][0]
# __________________________________________________________________________________________________
# layer_4/ln_1_add (Add)          (None, 512, 1024)    0           layer_3/ln_2[0][0]
#                                                                  layer_4/ln_1_drop[0][0]
# __________________________________________________________________________________________________
# layer_4/ln_1 (LayerNormalizatio (None, 512, 1024)    2048        layer_4/ln_1_add[0][0]
# __________________________________________________________________________________________________
# layer_4/c_fc (Conv1D)           (None, 512, 4096)    4198400     layer_4/ln_1[0][0]
# __________________________________________________________________________________________________
# layer_4/gelu (Gelu)             (None, 512, 4096)    0           layer_4/c_fc[0][0]
# __________________________________________________________________________________________________
# layer_4/c_ffn_proj (Conv1D)     (None, 512, 1024)    4195328     layer_4/gelu[0][0]
# __________________________________________________________________________________________________
# layer_4/ln_2_drop (Dropout)     (None, 512, 1024)    0           layer_4/c_ffn_proj[0][0]
# __________________________________________________________________________________________________
# layer_4/ln_2_add (Add)          (None, 512, 1024)    0           layer_4/ln_1[0][0]
#                                                                  layer_4/ln_2_drop[0][0]
# __________________________________________________________________________________________________
# layer_4/ln_2 (LayerNormalizatio (None, 512, 1024)    2048        layer_4/ln_2_add[0][0]
# __________________________________________________________________________________________________
# layer_5/c_attn (Conv1D)         (None, 512, 3072)    3148800     layer_4/ln_2[0][0]
# __________________________________________________________________________________________________
# layer_5/self_attention (MultiHe (None, 512, 1024)    0           layer_5/c_attn[0][0]
#                                                                  attention_mask_input[0][0]
# __________________________________________________________________________________________________
# layer_5/c_attn_proj (Conv1D)    (None, 512, 1024)    1049600     layer_5/self_attention[0][0]
# __________________________________________________________________________________________________
# layer_5/ln_1_drop (Dropout)     (None, 512, 1024)    0           layer_5/c_attn_proj[0][0]
# __________________________________________________________________________________________________
# layer_5/ln_1_add (Add)          (None, 512, 1024)    0           layer_4/ln_2[0][0]
#                                                                  layer_5/ln_1_drop[0][0]
# __________________________________________________________________________________________________
# layer_5/ln_1 (LayerNormalizatio (None, 512, 1024)    2048        layer_5/ln_1_add[0][0]
# __________________________________________________________________________________________________
# layer_5/c_fc (Conv1D)           (None, 512, 4096)    4198400     layer_5/ln_1[0][0]
# __________________________________________________________________________________________________
# layer_5/gelu (Gelu)             (None, 512, 4096)    0           layer_5/c_fc[0][0]
# __________________________________________________________________________________________________
# layer_5/c_ffn_proj (Conv1D)     (None, 512, 1024)    4195328     layer_5/gelu[0][0]
# __________________________________________________________________________________________________
# layer_5/ln_2_drop (Dropout)     (None, 512, 1024)    0           layer_5/c_ffn_proj[0][0]
# __________________________________________________________________________________________________
# layer_5/ln_2_add (Add)          (None, 512, 1024)    0           layer_5/ln_1[0][0]
#                                                                  layer_5/ln_2_drop[0][0]
# __________________________________________________________________________________________________
# layer_5/ln_2 (LayerNormalizatio (None, 512, 1024)    2048        layer_5/ln_2_add[0][0]
# __________________________________________________________________________________________________
# layer_6/c_attn (Conv1D)         (None, 512, 3072)    3148800     layer_5/ln_2[0][0]
# __________________________________________________________________________________________________
# layer_6/self_attention (MultiHe (None, 512, 1024)    0           layer_6/c_attn[0][0]
#                                                                  attention_mask_input[0][0]
# __________________________________________________________________________________________________
# layer_6/c_attn_proj (Conv1D)    (None, 512, 1024)    1049600     layer_6/self_attention[0][0]
# __________________________________________________________________________________________________
# layer_6/ln_1_drop (Dropout)     (None, 512, 1024)    0           layer_6/c_attn_proj[0][0]
# __________________________________________________________________________________________________
# layer_6/ln_1_add (Add)          (None, 512, 1024)    0           layer_5/ln_2[0][0]
#                                                                  layer_6/ln_1_drop[0][0]
# __________________________________________________________________________________________________
# layer_6/ln_1 (LayerNormalizatio (None, 512, 1024)    2048        layer_6/ln_1_add[0][0]
# __________________________________________________________________________________________________
# layer_6/c_fc (Conv1D)           (None, 512, 4096)    4198400     layer_6/ln_1[0][0]
# __________________________________________________________________________________________________
# layer_6/gelu (Gelu)             (None, 512, 4096)    0           layer_6/c_fc[0][0]
# __________________________________________________________________________________________________
# layer_6/c_ffn_proj (Conv1D)     (None, 512, 1024)    4195328     layer_6/gelu[0][0]
# __________________________________________________________________________________________________
# layer_6/ln_2_drop (Dropout)     (None, 512, 1024)    0           layer_6/c_ffn_proj[0][0]
# __________________________________________________________________________________________________
# layer_6/ln_2_add (Add)          (None, 512, 1024)    0           layer_6/ln_1[0][0]
#                                                                  layer_6/ln_2_drop[0][0]
# __________________________________________________________________________________________________
# layer_6/ln_2 (LayerNormalizatio (None, 512, 1024)    2048        layer_6/ln_2_add[0][0]
# __________________________________________________________________________________________________
# layer_7/c_attn (Conv1D)         (None, 512, 3072)    3148800     layer_6/ln_2[0][0]
# __________________________________________________________________________________________________
# layer_7/self_attention (MultiHe (None, 512, 1024)    0           layer_7/c_attn[0][0]
#                                                                  attention_mask_input[0][0]
# __________________________________________________________________________________________________
# layer_7/c_attn_proj (Conv1D)    (None, 512, 1024)    1049600     layer_7/self_attention[0][0]
# __________________________________________________________________________________________________
# layer_7/ln_1_drop (Dropout)     (None, 512, 1024)    0           layer_7/c_attn_proj[0][0]
# __________________________________________________________________________________________________
# layer_7/ln_1_add (Add)          (None, 512, 1024)    0           layer_6/ln_2[0][0]
#                                                                  layer_7/ln_1_drop[0][0]
# __________________________________________________________________________________________________
# layer_7/ln_1 (LayerNormalizatio (None, 512, 1024)    2048        layer_7/ln_1_add[0][0]
# __________________________________________________________________________________________________
# layer_7/c_fc (Conv1D)           (None, 512, 4096)    4198400     layer_7/ln_1[0][0]
# __________________________________________________________________________________________________
# layer_7/gelu (Gelu)             (None, 512, 4096)    0           layer_7/c_fc[0][0]
# __________________________________________________________________________________________________
# layer_7/c_ffn_proj (Conv1D)     (None, 512, 1024)    4195328     layer_7/gelu[0][0]
# __________________________________________________________________________________________________
# layer_7/ln_2_drop (Dropout)     (None, 512, 1024)    0           layer_7/c_ffn_proj[0][0]
# __________________________________________________________________________________________________
# layer_7/ln_2_add (Add)          (None, 512, 1024)    0           layer_7/ln_1[0][0]
#                                                                  layer_7/ln_2_drop[0][0]
# __________________________________________________________________________________________________
# layer_7/ln_2 (LayerNormalizatio (None, 512, 1024)    2048        layer_7/ln_2_add[0][0]
# __________________________________________________________________________________________________
# layer_8/c_attn (Conv1D)         (None, 512, 3072)    3148800     layer_7/ln_2[0][0]
# __________________________________________________________________________________________________
# layer_8/self_attention (MultiHe (None, 512, 1024)    0           layer_8/c_attn[0][0]
#                                                                  attention_mask_input[0][0]
# __________________________________________________________________________________________________
# layer_8/c_attn_proj (Conv1D)    (None, 512, 1024)    1049600     layer_8/self_attention[0][0]
# __________________________________________________________________________________________________
# layer_8/ln_1_drop (Dropout)     (None, 512, 1024)    0           layer_8/c_attn_proj[0][0]
# __________________________________________________________________________________________________
# layer_8/ln_1_add (Add)          (None, 512, 1024)    0           layer_7/ln_2[0][0]
#                                                                  layer_8/ln_1_drop[0][0]
# __________________________________________________________________________________________________
# layer_8/ln_1 (LayerNormalizatio (None, 512, 1024)    2048        layer_8/ln_1_add[0][0]
# __________________________________________________________________________________________________
# layer_8/c_fc (Conv1D)           (None, 512, 4096)    4198400     layer_8/ln_1[0][0]
# __________________________________________________________________________________________________
# layer_8/gelu (Gelu)             (None, 512, 4096)    0           layer_8/c_fc[0][0]
# __________________________________________________________________________________________________
# layer_8/c_ffn_proj (Conv1D)     (None, 512, 1024)    4195328     layer_8/gelu[0][0]
# __________________________________________________________________________________________________
# layer_8/ln_2_drop (Dropout)     (None, 512, 1024)    0           layer_8/c_ffn_proj[0][0]
# __________________________________________________________________________________________________
# layer_8/ln_2_add (Add)          (None, 512, 1024)    0           layer_8/ln_1[0][0]
#                                                                  layer_8/ln_2_drop[0][0]
# __________________________________________________________________________________________________
# layer_8/ln_2 (LayerNormalizatio (None, 512, 1024)    2048        layer_8/ln_2_add[0][0]
# __________________________________________________________________________________________________
# layer_9/c_attn (Conv1D)         (None, 512, 3072)    3148800     layer_8/ln_2[0][0]
# __________________________________________________________________________________________________
# layer_9/self_attention (MultiHe (None, 512, 1024)    0           layer_9/c_attn[0][0]
#                                                                  attention_mask_input[0][0]
# __________________________________________________________________________________________________
# layer_9/c_attn_proj (Conv1D)    (None, 512, 1024)    1049600     layer_9/self_attention[0][0]
# __________________________________________________________________________________________________
# layer_9/ln_1_drop (Dropout)     (None, 512, 1024)    0           layer_9/c_attn_proj[0][0]
# __________________________________________________________________________________________________
# layer_9/ln_1_add (Add)          (None, 512, 1024)    0           layer_8/ln_2[0][0]
#                                                                  layer_9/ln_1_drop[0][0]
# __________________________________________________________________________________________________
# layer_9/ln_1 (LayerNormalizatio (None, 512, 1024)    2048        layer_9/ln_1_add[0][0]
# __________________________________________________________________________________________________
# layer_9/c_fc (Conv1D)           (None, 512, 4096)    4198400     layer_9/ln_1[0][0]
# __________________________________________________________________________________________________
# layer_9/gelu (Gelu)             (None, 512, 4096)    0           layer_9/c_fc[0][0]
# __________________________________________________________________________________________________
# layer_9/c_ffn_proj (Conv1D)     (None, 512, 1024)    4195328     layer_9/gelu[0][0]
# __________________________________________________________________________________________________
# layer_9/ln_2_drop (Dropout)     (None, 512, 1024)    0           layer_9/c_ffn_proj[0][0]
# __________________________________________________________________________________________________
# layer_9/ln_2_add (Add)          (None, 512, 1024)    0           layer_9/ln_1[0][0]
#                                                                  layer_9/ln_2_drop[0][0]
# __________________________________________________________________________________________________
# layer_9/ln_2 (LayerNormalizatio (None, 512, 1024)    2048        layer_9/ln_2_add[0][0]
# __________________________________________________________________________________________________
# layer_10/c_attn (Conv1D)        (None, 512, 3072)    3148800     layer_9/ln_2[0][0]
# __________________________________________________________________________________________________
# layer_10/self_attention (MultiH (None, 512, 1024)    0           layer_10/c_attn[0][0]
#                                                                  attention_mask_input[0][0]
# __________________________________________________________________________________________________
# layer_10/c_attn_proj (Conv1D)   (None, 512, 1024)    1049600     layer_10/self_attention[0][0]
# __________________________________________________________________________________________________
# layer_10/ln_1_drop (Dropout)    (None, 512, 1024)    0           layer_10/c_attn_proj[0][0]
# __________________________________________________________________________________________________
# layer_10/ln_1_add (Add)         (None, 512, 1024)    0           layer_9/ln_2[0][0]
#                                                                  layer_10/ln_1_drop[0][0]
# __________________________________________________________________________________________________
# layer_10/ln_1 (LayerNormalizati (None, 512, 1024)    2048        layer_10/ln_1_add[0][0]
# __________________________________________________________________________________________________
# layer_10/c_fc (Conv1D)          (None, 512, 4096)    4198400     layer_10/ln_1[0][0]
# __________________________________________________________________________________________________
# layer_10/gelu (Gelu)            (None, 512, 4096)    0           layer_10/c_fc[0][0]
# __________________________________________________________________________________________________
# layer_10/c_ffn_proj (Conv1D)    (None, 512, 1024)    4195328     layer_10/gelu[0][0]
# __________________________________________________________________________________________________
# layer_10/ln_2_drop (Dropout)    (None, 512, 1024)    0           layer_10/c_ffn_proj[0][0]
# __________________________________________________________________________________________________
# layer_10/ln_2_add (Add)         (None, 512, 1024)    0           layer_10/ln_1[0][0]
#                                                                  layer_10/ln_2_drop[0][0]
# __________________________________________________________________________________________________
# layer_10/ln_2 (LayerNormalizati (None, 512, 1024)    2048        layer_10/ln_2_add[0][0]
# __________________________________________________________________________________________________
# layer_11/c_attn (Conv1D)        (None, 512, 3072)    3148800     layer_10/ln_2[0][0]
# __________________________________________________________________________________________________
# layer_11/self_attention (MultiH (None, 512, 1024)    0           layer_11/c_attn[0][0]
#                                                                  attention_mask_input[0][0]
# __________________________________________________________________________________________________
# layer_11/c_attn_proj (Conv1D)   (None, 512, 1024)    1049600     layer_11/self_attention[0][0]
# __________________________________________________________________________________________________
# layer_11/ln_1_drop (Dropout)    (None, 512, 1024)    0           layer_11/c_attn_proj[0][0]
# __________________________________________________________________________________________________
# layer_11/ln_1_add (Add)         (None, 512, 1024)    0           layer_10/ln_2[0][0]
#                                                                  layer_11/ln_1_drop[0][0]
# __________________________________________________________________________________________________
# layer_11/ln_1 (LayerNormalizati (None, 512, 1024)    2048        layer_11/ln_1_add[0][0]
# __________________________________________________________________________________________________
# layer_11/c_fc (Conv1D)          (None, 512, 4096)    4198400     layer_11/ln_1[0][0]
# __________________________________________________________________________________________________
# layer_11/gelu (Gelu)            (None, 512, 4096)    0           layer_11/c_fc[0][0]
# __________________________________________________________________________________________________
# layer_11/c_ffn_proj (Conv1D)    (None, 512, 1024)    4195328     layer_11/gelu[0][0]
# __________________________________________________________________________________________________
# layer_11/ln_2_drop (Dropout)    (None, 512, 1024)    0           layer_11/c_ffn_proj[0][0]
# __________________________________________________________________________________________________
# layer_11/ln_2_add (Add)         (None, 512, 1024)    0           layer_11/ln_1[0][0]
#                                                                  layer_11/ln_2_drop[0][0]
# __________________________________________________________________________________________________
# layer_11/ln_2 (LayerNormalizati (None, 512, 1024)    2048        layer_11/ln_2_add[0][0]
# __________________________________________________________________________________________________
# layer_12/c_attn (Conv1D)        (None, 512, 3072)    3148800     layer_11/ln_2[0][0]
# __________________________________________________________________________________________________
# layer_12/self_attention (MultiH (None, 512, 1024)    0           layer_12/c_attn[0][0]
#                                                                  attention_mask_input[0][0]
# __________________________________________________________________________________________________
# layer_12/c_attn_proj (Conv1D)   (None, 512, 1024)    1049600     layer_12/self_attention[0][0]
# __________________________________________________________________________________________________
# layer_12/ln_1_drop (Dropout)    (None, 512, 1024)    0           layer_12/c_attn_proj[0][0]
# __________________________________________________________________________________________________
# layer_12/ln_1_add (Add)         (None, 512, 1024)    0           layer_11/ln_2[0][0]
#                                                                  layer_12/ln_1_drop[0][0]
# __________________________________________________________________________________________________
# layer_12/ln_1 (LayerNormalizati (None, 512, 1024)    2048        layer_12/ln_1_add[0][0]
# __________________________________________________________________________________________________
# layer_12/c_fc (Conv1D)          (None, 512, 4096)    4198400     layer_12/ln_1[0][0]
# __________________________________________________________________________________________________
# layer_12/gelu (Gelu)            (None, 512, 4096)    0           layer_12/c_fc[0][0]
# __________________________________________________________________________________________________
# layer_12/c_ffn_proj (Conv1D)    (None, 512, 1024)    4195328     layer_12/gelu[0][0]
# __________________________________________________________________________________________________
# layer_12/ln_2_drop (Dropout)    (None, 512, 1024)    0           layer_12/c_ffn_proj[0][0]
# __________________________________________________________________________________________________
# layer_12/ln_2_add (Add)         (None, 512, 1024)    0           layer_12/ln_1[0][0]
#                                                                  layer_12/ln_2_drop[0][0]
# __________________________________________________________________________________________________
# layer_12/ln_2 (LayerNormalizati (None, 512, 1024)    2048        layer_12/ln_2_add[0][0]
# __________________________________________________________________________________________________
# layer_13/c_attn (Conv1D)        (None, 512, 3072)    3148800     layer_12/ln_2[0][0]
# __________________________________________________________________________________________________
# layer_13/self_attention (MultiH (None, 512, 1024)    0           layer_13/c_attn[0][0]
#                                                                  attention_mask_input[0][0]
# __________________________________________________________________________________________________
# layer_13/c_attn_proj (Conv1D)   (None, 512, 1024)    1049600     layer_13/self_attention[0][0]
# __________________________________________________________________________________________________
# layer_13/ln_1_drop (Dropout)    (None, 512, 1024)    0           layer_13/c_attn_proj[0][0]
# __________________________________________________________________________________________________
# layer_13/ln_1_add (Add)         (None, 512, 1024)    0           layer_12/ln_2[0][0]
#                                                                  layer_13/ln_1_drop[0][0]
# __________________________________________________________________________________________________
# layer_13/ln_1 (LayerNormalizati (None, 512, 1024)    2048        layer_13/ln_1_add[0][0]
# __________________________________________________________________________________________________
# layer_13/c_fc (Conv1D)          (None, 512, 4096)    4198400     layer_13/ln_1[0][0]
# __________________________________________________________________________________________________
# layer_13/gelu (Gelu)            (None, 512, 4096)    0           layer_13/c_fc[0][0]
# __________________________________________________________________________________________________
# layer_13/c_ffn_proj (Conv1D)    (None, 512, 1024)    4195328     layer_13/gelu[0][0]
# __________________________________________________________________________________________________
# layer_13/ln_2_drop (Dropout)    (None, 512, 1024)    0           layer_13/c_ffn_proj[0][0]
# __________________________________________________________________________________________________
# layer_13/ln_2_add (Add)         (None, 512, 1024)    0           layer_13/ln_1[0][0]
#                                                                  layer_13/ln_2_drop[0][0]
# __________________________________________________________________________________________________
# layer_13/ln_2 (LayerNormalizati (None, 512, 1024)    2048        layer_13/ln_2_add[0][0]
# __________________________________________________________________________________________________
# layer_14/c_attn (Conv1D)        (None, 512, 3072)    3148800     layer_13/ln_2[0][0]
# __________________________________________________________________________________________________
# layer_14/self_attention (MultiH (None, 512, 1024)    0           layer_14/c_attn[0][0]
#                                                                  attention_mask_input[0][0]
# __________________________________________________________________________________________________
# layer_14/c_attn_proj (Conv1D)   (None, 512, 1024)    1049600     layer_14/self_attention[0][0]
# __________________________________________________________________________________________________
# layer_14/ln_1_drop (Dropout)    (None, 512, 1024)    0           layer_14/c_attn_proj[0][0]
# __________________________________________________________________________________________________
# layer_14/ln_1_add (Add)         (None, 512, 1024)    0           layer_13/ln_2[0][0]
#                                                                  layer_14/ln_1_drop[0][0]
# __________________________________________________________________________________________________
# layer_14/ln_1 (LayerNormalizati (None, 512, 1024)    2048        layer_14/ln_1_add[0][0]
# __________________________________________________________________________________________________
# layer_14/c_fc (Conv1D)          (None, 512, 4096)    4198400     layer_14/ln_1[0][0]
# __________________________________________________________________________________________________
# layer_14/gelu (Gelu)            (None, 512, 4096)    0           layer_14/c_fc[0][0]
# __________________________________________________________________________________________________
# layer_14/c_ffn_proj (Conv1D)    (None, 512, 1024)    4195328     layer_14/gelu[0][0]
# __________________________________________________________________________________________________
# layer_14/ln_2_drop (Dropout)    (None, 512, 1024)    0           layer_14/c_ffn_proj[0][0]
# __________________________________________________________________________________________________
# layer_14/ln_2_add (Add)         (None, 512, 1024)    0           layer_14/ln_1[0][0]
#                                                                  layer_14/ln_2_drop[0][0]
# __________________________________________________________________________________________________
# layer_14/ln_2 (LayerNormalizati (None, 512, 1024)    2048        layer_14/ln_2_add[0][0]
# __________________________________________________________________________________________________
# layer_15/c_attn (Conv1D)        (None, 512, 3072)    3148800     layer_14/ln_2[0][0]
# __________________________________________________________________________________________________
# layer_15/self_attention (MultiH (None, 512, 1024)    0           layer_15/c_attn[0][0]
#                                                                  attention_mask_input[0][0]
# __________________________________________________________________________________________________
# layer_15/c_attn_proj (Conv1D)   (None, 512, 1024)    1049600     layer_15/self_attention[0][0]
# __________________________________________________________________________________________________
# layer_15/ln_1_drop (Dropout)    (None, 512, 1024)    0           layer_15/c_attn_proj[0][0]
# __________________________________________________________________________________________________
# layer_15/ln_1_add (Add)         (None, 512, 1024)    0           layer_14/ln_2[0][0]
#                                                                  layer_15/ln_1_drop[0][0]
# __________________________________________________________________________________________________
# layer_15/ln_1 (LayerNormalizati (None, 512, 1024)    2048        layer_15/ln_1_add[0][0]
# __________________________________________________________________________________________________
# layer_15/c_fc (Conv1D)          (None, 512, 4096)    4198400     layer_15/ln_1[0][0]
# __________________________________________________________________________________________________
# layer_15/gelu (Gelu)            (None, 512, 4096)    0           layer_15/c_fc[0][0]
# __________________________________________________________________________________________________
# layer_15/c_ffn_proj (Conv1D)    (None, 512, 1024)    4195328     layer_15/gelu[0][0]
# __________________________________________________________________________________________________
# layer_15/ln_2_drop (Dropout)    (None, 512, 1024)    0           layer_15/c_ffn_proj[0][0]
# __________________________________________________________________________________________________
# layer_15/ln_2_add (Add)         (None, 512, 1024)    0           layer_15/ln_1[0][0]
#                                                                  layer_15/ln_2_drop[0][0]
# __________________________________________________________________________________________________
# layer_15/ln_2 (LayerNormalizati (None, 512, 1024)    2048        layer_15/ln_2_add[0][0]
# __________________________________________________________________________________________________
# layer_16/c_attn (Conv1D)        (None, 512, 3072)    3148800     layer_15/ln_2[0][0]
# __________________________________________________________________________________________________
# layer_16/self_attention (MultiH (None, 512, 1024)    0           layer_16/c_attn[0][0]
#                                                                  attention_mask_input[0][0]
# __________________________________________________________________________________________________
# layer_16/c_attn_proj (Conv1D)   (None, 512, 1024)    1049600     layer_16/self_attention[0][0]
# __________________________________________________________________________________________________
# layer_16/ln_1_drop (Dropout)    (None, 512, 1024)    0           layer_16/c_attn_proj[0][0]
# __________________________________________________________________________________________________
# layer_16/ln_1_add (Add)         (None, 512, 1024)    0           layer_15/ln_2[0][0]
#                                                                  layer_16/ln_1_drop[0][0]
# __________________________________________________________________________________________________
# layer_16/ln_1 (LayerNormalizati (None, 512, 1024)    2048        layer_16/ln_1_add[0][0]
# __________________________________________________________________________________________________
# layer_16/c_fc (Conv1D)          (None, 512, 4096)    4198400     layer_16/ln_1[0][0]
# __________________________________________________________________________________________________
# layer_16/gelu (Gelu)            (None, 512, 4096)    0           layer_16/c_fc[0][0]
# __________________________________________________________________________________________________
# layer_16/c_ffn_proj (Conv1D)    (None, 512, 1024)    4195328     layer_16/gelu[0][0]
# __________________________________________________________________________________________________
# layer_16/ln_2_drop (Dropout)    (None, 512, 1024)    0           layer_16/c_ffn_proj[0][0]
# __________________________________________________________________________________________________
# layer_16/ln_2_add (Add)         (None, 512, 1024)    0           layer_16/ln_1[0][0]
#                                                                  layer_16/ln_2_drop[0][0]
# __________________________________________________________________________________________________
# layer_16/ln_2 (LayerNormalizati (None, 512, 1024)    2048        layer_16/ln_2_add[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# layer_18/self_attention (MultiH (None, 512, 1024)    0           layer_18/c_attn[0][0]
#                                                                  attention_mask_input[0][0]
# __________________________________________________________________________________________________
# layer_18/c_attn_proj (Conv1D)   (None, 512, 1024)    1049600     layer_18/self_attention[0][0]
# __________________________________________________________________________________________________
# layer_18/ln_1_drop (Dropout)    (None, 512, 1024)    0           layer_18/c_attn_proj[0][0]
# __________________________________________________________________________________________________
# layer_18/ln_1_add (Add)         (None, 512, 1024)    0           layer_17/ln_2[0][0]
#                                                                  layer_18/ln_1_drop[0][0]
# __________________________________________________________________________________________________
# layer_18/ln_1 (LayerNormalizati (None, 512, 1024)    2048        layer_18/ln_1_add[0][0]
# __________________________________________________________________________________________________
# layer_18/c_fc (Conv1D)          (None, 512, 4096)    4198400     layer_18/ln_1[0][0]
# __________________________________________________________________________________________________
# layer_18/gelu (Gelu)            (None, 512, 4096)    0           layer_18/c_fc[0][0]
# __________________________________________________________________________________________________
# layer_18/c_ffn_proj (Conv1D)    (None, 512, 1024)    4195328     layer_18/gelu[0][0]
# __________________________________________________________________________________________________
# layer_18/ln_2_drop (Dropout)    (None, 512, 1024)    0           layer_18/c_ffn_proj[0][0]
# __________________________________________________________________________________________________
# layer_18/ln_2_add (Add)         (None, 512, 1024)    0           layer_18/ln_1[0][0]
#                                                                  layer_18/ln_2_drop[0][0]
# __________________________________________________________________________________________________
# layer_18/ln_2 (LayerNormalizati (None, 512, 1024)    2048        layer_18/ln_2_add[0][0]
# __________________________________________________________________________________________________
# layer_19/c_attn (Conv1D)        (None, 512, 3072)    3148800     layer_18/ln_2[0][0]
# __________________________________________________________________________________________________
# layer_19/self_attention (MultiH (None, 512, 1024)    0           layer_19/c_attn[0][0]
#                                                                  attention_mask_input[0][0]
# __________________________________________________________________________________________________
# layer_19/c_attn_proj (Conv1D)   (None, 512, 1024)    1049600     layer_19/self_attention[0][0]
# __________________________________________________________________________________________________
# layer_19/ln_1_drop (Dropout)    (None, 512, 1024)    0           layer_19/c_attn_proj[0][0]
# __________________________________________________________________________________________________
# layer_19/ln_1_add (Add)         (None, 512, 1024)    0           layer_18/ln_2[0][0]
#                                                                  layer_19/ln_1_drop[0][0]
# __________________________________________________________________________________________________
# layer_19/ln_1 (LayerNormalizati (None, 512, 1024)    2048        layer_19/ln_1_add[0][0]
# __________________________________________________________________________________________________
# layer_19/c_fc (Conv1D)          (None, 512, 4096)    4198400     layer_19/ln_1[0][0]
# __________________________________________________________________________________________________
# layer_19/gelu (Gelu)            (None, 512, 4096)    0           layer_19/c_fc[0][0]
# __________________________________________________________________________________________________
# layer_19/c_ffn_proj (Conv1D)    (None, 512, 1024)    4195328     layer_19/gelu[0][0]
# __________________________________________________________________________________________________
# layer_19/ln_2_drop (Dropout)    (None, 512, 1024)    0           layer_19/c_ffn_proj[0][0]
# __________________________________________________________________________________________________
# layer_19/ln_2_add (Add)         (None, 512, 1024)    0           layer_19/ln_1[0][0]
#                                                                  layer_19/ln_2_drop[0][0]
# __________________________________________________________________________________________________
# layer_19/ln_2 (LayerNormalizati (None, 512, 1024)    2048        layer_19/ln_2_add[0][0]
# __________________________________________________________________________________________________
# layer_20/c_attn (Conv1D)        (None, 512, 3072)    3148800     layer_19/ln_2[0][0]
# __________________________________________________________________________________________________
# layer_20/self_attention (MultiH (None, 512, 1024)    0           layer_20/c_attn[0][0]
#                                                                  attention_mask_input[0][0]
# __________________________________________________________________________________________________
# layer_20/c_attn_proj (Conv1D)   (None, 512, 1024)    1049600     layer_20/self_attention[0][0]
# __________________________________________________________________________________________________
# layer_20/ln_1_drop (Dropout)    (None, 512, 1024)    0           layer_20/c_attn_proj[0][0]
# __________________________________________________________________________________________________
# layer_20/ln_1_add (Add)         (None, 512, 1024)    0           layer_19/ln_2[0][0]
#                                                                  layer_20/ln_1_drop[0][0]
# __________________________________________________________________________________________________
# layer_20/ln_1 (LayerNormalizati (None, 512, 1024)    2048        layer_20/ln_1_add[0][0]
# __________________________________________________________________________________________________
# layer_20/c_fc (Conv1D)          (None, 512, 4096)    4198400     layer_20/ln_1[0][0]
# __________________________________________________________________________________________________
# layer_20/gelu (Gelu)            (None, 512, 4096)    0           layer_20/c_fc[0][0]
# __________________________________________________________________________________________________
# layer_20/c_ffn_proj (Conv1D)    (None, 512, 1024)    4195328     layer_20/gelu[0][0]
# __________________________________________________________________________________________________
# layer_20/ln_2_drop (Dropout)    (None, 512, 1024)    0           layer_20/c_ffn_proj[0][0]
# __________________________________________________________________________________________________
# layer_20/ln_2_add (Add)         (None, 512, 1024)    0           layer_20/ln_1[0][0]
#                                                                  layer_20/ln_2_drop[0][0]
# __________________________________________________________________________________________________
# layer_20/ln_2 (LayerNormalizati (None, 512, 1024)    2048        layer_20/ln_2_add[0][0]
# __________________________________________________________________________________________________
# layer_21/c_attn (Conv1D)        (None, 512, 3072)    3148800     layer_20/ln_2[0][0]
# __________________________________________________________________________________________________
# layer_21/self_attention (MultiH (None, 512, 1024)    0           layer_21/c_attn[0][0]
#                                                                  attention_mask_input[0][0]
# __________________________________________________________________________________________________
# layer_21/c_attn_proj (Conv1D)   (None, 512, 1024)    1049600     layer_21/self_attention[0][0]
# __________________________________________________________________________________________________
# layer_21/ln_1_drop (Dropout)    (None, 512, 1024)    0           layer_21/c_attn_proj[0][0]
# __________________________________________________________________________________________________
# layer_21/ln_1_add (Add)         (None, 512, 1024)    0           layer_20/ln_2[0][0]
#                                                                  layer_21/ln_1_drop[0][0]
# __________________________________________________________________________________________________
# layer_21/ln_1 (LayerNormalizati (None, 512, 1024)    2048        layer_21/ln_1_add[0][0]
# __________________________________________________________________________________________________
# layer_21/c_fc (Conv1D)          (None, 512, 4096)    4198400     layer_21/ln_1[0][0]
# __________________________________________________________________________________________________
# layer_21/gelu (Gelu)            (None, 512, 4096)    0           layer_21/c_fc[0][0]
# __________________________________________________________________________________________________
# layer_21/c_ffn_proj (Conv1D)    (None, 512, 1024)    4195328     layer_21/gelu[0][0]
# __________________________________________________________________________________________________
# layer_21/ln_2_drop (Dropout)    (None, 512, 1024)    0           layer_21/c_ffn_proj[0][0]
# __________________________________________________________________________________________________
# layer_21/ln_2_add (Add)         (None, 512, 1024)    0           layer_21/ln_1[0][0]
#                                                                  layer_21/ln_2_drop[0][0]
# __________________________________________________________________________________________________
# layer_21/ln_2 (LayerNormalizati (None, 512, 1024)    2048        layer_21/ln_2_add[0][0]
# __________________________________________________________________________________________________
# layer_22/c_attn (Conv1D)        (None, 512, 3072)    3148800     layer_21/ln_2[0][0]
# __________________________________________________________________________________________________
# layer_22/self_attention (MultiH (None, 512, 1024)    0           layer_22/c_attn[0][0]
#                                                                  attention_mask_input[0][0]
# __________________________________________________________________________________________________
# layer_22/c_attn_proj (Conv1D)   (None, 512, 1024)    1049600     layer_22/self_attention[0][0]
# __________________________________________________________________________________________________
# layer_22/ln_1_drop (Dropout)    (None, 512, 1024)    0           layer_22/c_attn_proj[0][0]
# __________________________________________________________________________________________________
# layer_22/ln_1_add (Add)         (None, 512, 1024)    0           layer_21/ln_2[0][0]
#                                                                  layer_22/ln_1_drop[0][0]
# __________________________________________________________________________________________________
# layer_22/ln_1 (LayerNormalizati (None, 512, 1024)    2048        layer_22/ln_1_add[0][0]
# __________________________________________________________________________________________________
# layer_22/c_fc (Conv1D)          (None, 512, 4096)    4198400     layer_22/ln_1[0][0]
# __________________________________________________________________________________________________
# layer_22/gelu (Gelu)            (None, 512, 4096)    0           layer_22/c_fc[0][0]
# __________________________________________________________________________________________________
# layer_22/c_ffn_proj (Conv1D)    (None, 512, 1024)    4195328     layer_22/gelu[0][0]
# __________________________________________________________________________________________________
# layer_22/ln_2_drop (Dropout)    (None, 512, 1024)    0           layer_22/c_ffn_proj[0][0]
# __________________________________________________________________________________________________
# layer_22/ln_2_add (Add)         (None, 512, 1024)    0           layer_22/ln_1[0][0]
#                                                                  layer_22/ln_2_drop[0][0]
# __________________________________________________________________________________________________
# layer_22/ln_2 (LayerNormalizati (None, 512, 1024)    2048        layer_22/ln_2_add[0][0]
# __________________________________________________________________________________________________
# layer_23/c_attn (Conv1D)        (None, 512, 3072)    3148800     layer_22/ln_2[0][0]
# __________________________________________________________________________________________________
# layer_23/self_attention (MultiH (None, 512, 1024)    0           layer_23/c_attn[0][0]
#                                                                  attention_mask_input[0][0]
# __________________________________________________________________________________________________
# layer_23/c_attn_proj (Conv1D)   (None, 512, 1024)    1049600     layer_23/self_attention[0][0]
# __________________________________________________________________________________________________
# layer_23/ln_1_drop (Dropout)    (None, 512, 1024)    0           layer_23/c_attn_proj[0][0]
# __________________________________________________________________________________________________
# layer_23/ln_1_add (Add)         (None, 512, 1024)    0           layer_22/ln_2[0][0]
#                                                                  layer_23/ln_1_drop[0][0]
# __________________________________________________________________________________________________
# layer_23/ln_1 (LayerNormalizati (None, 512, 1024)    2048        layer_23/ln_1_add[0][0]
# __________________________________________________________________________________________________
# layer_23/c_fc (Conv1D)          (None, 512, 4096)    4198400     layer_23/ln_1[0][0]
# __________________________________________________________________________________________________
# layer_23/gelu (Gelu)            (None, 512, 4096)    0           layer_23/c_fc[0][0]
# __________________________________________________________________________________________________
# layer_23/c_ffn_proj (Conv1D)    (None, 512, 1024)    4195328     layer_23/gelu[0][0]
# __________________________________________________________________________________________________
# layer_23/ln_2_drop (Dropout)    (None, 512, 1024)    0           layer_23/c_ffn_proj[0][0]
# __________________________________________________________________________________________________
# layer_23/ln_2_add (Add)         (None, 512, 1024)    0           layer_23/ln_1[0][0]
#                                                                  layer_23/ln_2_drop[0][0]
# ==================================================================================================
# Total params: 332,427,264
# Trainable params: 0
# Non-trainable params: 332,427,264
# __________________________________________________________________________________________________

# %%
from multiprocessing import Pool
pool = Pool(30)
X = pool.map(get_features, marvel['bio'])
#X = []

#for row in marvel.iterrows():
#  X.append(get_features(row[1]['bio']))
# Out:
# W0620 14:04:58.840658 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:305: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# W0620 14:04:59.174604 139746805892992 estimator.py:1984] Estimator's model_fn (<function model_fn_builder.<locals>.model_fn at 0x7f19065066a8>) includes params argument, but params are not passed to Estimator.
# W0620 14:04:59.178774 139746805892992 estimator.py:1811] Using temporary folder as model directory: /tmp/tmp1e1akrdq
# W0620 14:04:59.532645 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:305: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# W0620 14:04:59.609023 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:305: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
# W0620 14:04:59.572893 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:305: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
# W0620 14:04:59.548301 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:305: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
# W0620 14:04:59.624609 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:305: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
# W0620 14:04:59.634589 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:305: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
# W0620 14:04:59.625304 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:305: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
# W0620 14:04:59.628578 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:305: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
#
#
# W0620 14:04:59.633891 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:305: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
# W0620 14:04:59.628199 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:305: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
# W0620 14:04:59.658744 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:305: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
# W0620 14:04:59.657626 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:305: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
#
#
#
# W0620 14:04:59.694642 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:305: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
# W0620 14:04:59.698048 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:305: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# W0620 14:04:59.670505 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:305: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
#
# W0620 14:04:59.722697 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:305: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
# W0620 14:04:59.713744 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:305: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
#
#
#
#
#
# W0620 14:04:59.836427 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:305: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# W0620 14:04:59.813612 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:305: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
# W0620 14:04:59.882801 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:305: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
#
# W0620 14:04:59.937247 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:305: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
# W0620 14:04:59.930778 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:305: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
# W0620 14:04:59.965789 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:305: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
#
#
# W0620 14:05:00.209155 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:305: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
# W0620 14:05:00.226569 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:305: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# W0620 14:05:00.264213 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:305: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
#
# W0620 14:05:00.231912 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:305: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# W0620 14:05:00.511081 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:305: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# W0620 14:05:00.601513 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:305: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# W0620 14:05:04.272727 139746805892992 estimator.py:1984] Estimator's model_fn (<function model_fn_builder.<locals>.model_fn at 0x7f19065066a8>) includes params argument, but params are not passed to Estimator.
# W0620 14:05:04.341277 139746805892992 estimator.py:1811] Using temporary folder as model directory: /tmp/tmp1mw_7kt2
# W0620 14:05:06.308736 139746805892992 estimator.py:1984] Estimator's model_fn (<function model_fn_builder.<locals>.model_fn at 0x7f19065066a8>) includes params argument, but params are not passed to Estimator.
# W0620 14:05:06.375497 139746805892992 estimator.py:1811] Using temporary folder as model directory: /tmp/tmp9tiyosic
# W0620 14:05:06.533968 139746805892992 estimator.py:1984] Estimator's model_fn (<function model_fn_builder.<locals>.model_fn at 0x7f19065066a8>) includes params argument, but params are not passed to Estimator.
# W0620 14:05:06.591667 139746805892992 estimator.py:1811] Using temporary folder as model directory: /tmp/tmpsj0dh64_
# W0620 14:05:08.074676 139746805892992 estimator.py:1984] Estimator's model_fn (<function model_fn_builder.<locals>.model_fn at 0x7f19065066a8>) includes params argument, but params are not passed to Estimator.
# W0620 14:05:08.140086 139746805892992 estimator.py:1811] Using temporary folder as model directory: /tmp/tmpyehtnh2m
# W0620 14:05:08.908469 139746805892992 estimator.py:1984] Estimator's model_fn (<function model_fn_builder.<locals>.model_fn at 0x7f19065066a8>) includes params argument, but params are not passed to Estimator.
# W0620 14:05:08.982759 139746805892992 estimator.py:1811] Using temporary folder as model directory: /tmp/tmpnlq9knu3
# W0620 14:05:09.227450 139746805892992 estimator.py:1984] Estimator's model_fn (<function model_fn_builder.<locals>.model_fn at 0x7f19065066a8>) includes params argument, but params are not passed to Estimator.
# W0620 14:05:09.303490 139746805892992 estimator.py:1811] Using temporary folder as model directory: /tmp/tmpes0bxc15
# W0620 14:05:09.753512 139746805892992 estimator.py:1984] Estimator's model_fn (<function model_fn_builder.<locals>.model_fn at 0x7f19065066a8>) includes params argument, but params are not passed to Estimator.
# W0620 14:05:09.798921 139746805892992 estimator.py:1811] Using temporary folder as model directory: /tmp/tmpes2co_gp
# W0620 14:05:09.920483 139746805892992 estimator.py:1984] Estimator's model_fn (<function model_fn_builder.<locals>.model_fn at 0x7f19065066a8>) includes params argument, but params are not passed to Estimator.
# W0620 14:05:09.987226 139746805892992 estimator.py:1811] Using temporary folder as model directory: /tmp/tmpol5qyeb5
# W0620 14:05:10.746749 139746805892992 estimator.py:1984] Estimator's model_fn (<function model_fn_builder.<locals>.model_fn at 0x7f19065066a8>) includes params argument, but params are not passed to Estimator.
# W0620 14:05:10.821739 139746805892992 estimator.py:1811] Using temporary folder as model directory: /tmp/tmpza_ejdqr
# W0620 14:05:11.232533 139746805892992 estimator.py:1984] Estimator's model_fn (<function model_fn_builder.<locals>.model_fn at 0x7f19065066a8>) includes params argument, but params are not passed to Estimator.
# W0620 14:05:11.288146 139746805892992 estimator.py:1811] Using temporary folder as model directory: /tmp/tmp887x_f1t
# W0620 14:05:11.754964 139746805892992 estimator.py:1984] Estimator's model_fn (<function model_fn_builder.<locals>.model_fn at 0x7f19065066a8>) includes params argument, but params are not passed to Estimator.
# W0620 14:05:11.796016 139746805892992 estimator.py:1811] Using temporary folder as model directory: /tmp/tmpsi69g9wt
# W0620 14:05:12.219847 139746805892992 estimator.py:1984] Estimator's model_fn (<function model_fn_builder.<locals>.model_fn at 0x7f19065066a8>) includes params argument, but params are not passed to Estimator.
# W0620 14:05:12.210890 139746805892992 estimator.py:1984] Estimator's model_fn (<function model_fn_builder.<locals>.model_fn at 0x7f19065066a8>) includes params argument, but params are not passed to Estimator.
# W0620 14:05:12.265614 139746805892992 estimator.py:1811] Using temporary folder as model directory: /tmp/tmppmc_q5x6
# W0620 14:05:12.276575 139746805892992 estimator.py:1811] Using temporary folder as model directory: /tmp/tmp83tqmq1g
# W0620 14:05:12.914475 139746805892992 estimator.py:1984] Estimator's model_fn (<function model_fn_builder.<locals>.model_fn at 0x7f19065066a8>) includes params argument, but params are not passed to Estimator.
# W0620 14:05:12.985239 139746805892992 estimator.py:1811] Using temporary folder as model directory: /tmp/tmpmolftv06
# W0620 14:05:13.198135 139746805892992 estimator.py:1984] Estimator's model_fn (<function model_fn_builder.<locals>.model_fn at 0x7f19065066a8>) includes params argument, but params are not passed to Estimator.
# W0620 14:05:13.244545 139746805892992 estimator.py:1811] Using temporary folder as model directory: /tmp/tmp8t3e4nqo
# W0620 14:05:13.907809 139746805892992 estimator.py:1984] Estimator's model_fn (<function model_fn_builder.<locals>.model_fn at 0x7f19065066a8>) includes params argument, but params are not passed to Estimator.
# W0620 14:05:13.949221 139746805892992 estimator.py:1811] Using temporary folder as model directory: /tmp/tmp3lcsol9w
# W0620 14:05:16.645705 139746805892992 estimator.py:1984] Estimator's model_fn (<function model_fn_builder.<locals>.model_fn at 0x7f19065066a8>) includes params argument, but params are not passed to Estimator.
# W0620 14:05:16.688720 139746805892992 estimator.py:1811] Using temporary folder as model directory: /tmp/tmp4we3p6nk
# W0620 14:05:16.812111 139746805892992 estimator.py:1984] Estimator's model_fn (<function model_fn_builder.<locals>.model_fn at 0x7f19065066a8>) includes params argument, but params are not passed to Estimator.
# W0620 14:05:16.878592 139746805892992 estimator.py:1811] Using temporary folder as model directory: /tmp/tmp0291lz3f
# W0620 14:05:17.218865 139746805892992 estimator.py:1984] Estimator's model_fn (<function model_fn_builder.<locals>.model_fn at 0x7f19065066a8>) includes params argument, but params are not passed to Estimator.
# W0620 14:05:17.294338 139746805892992 estimator.py:1811] Using temporary folder as model directory: /tmp/tmp82q_bmcf
# W0620 14:05:18.560824 139746805892992 estimator.py:1984] Estimator's model_fn (<function model_fn_builder.<locals>.model_fn at 0x7f19065066a8>) includes params argument, but params are not passed to Estimator.
# W0620 14:05:18.593552 139746805892992 estimator.py:1811] Using temporary folder as model directory: /tmp/tmpib9vzzwt
# W0620 14:05:20.339852 139746805892992 estimator.py:1984] Estimator's model_fn (<function model_fn_builder.<locals>.model_fn at 0x7f19065066a8>) includes params argument, but params are not passed to Estimator.
# W0620 14:05:20.383290 139746805892992 estimator.py:1811] Using temporary folder as model directory: /tmp/tmp6a01lwk0
# W0620 14:05:21.308305 139746805892992 estimator.py:1984] Estimator's model_fn (<function model_fn_builder.<locals>.model_fn at 0x7f19065066a8>) includes params argument, but params are not passed to Estimator.
# W0620 14:05:21.389377 139746805892992 estimator.py:1811] Using temporary folder as model directory: /tmp/tmp435rhmnf
# W0620 14:05:21.577372 139746805892992 estimator.py:1984] Estimator's model_fn (<function model_fn_builder.<locals>.model_fn at 0x7f19065066a8>) includes params argument, but params are not passed to Estimator.
# W0620 14:05:21.629374 139746805892992 estimator.py:1811] Using temporary folder as model directory: /tmp/tmpjtynu3_l
# W0620 14:05:40.995834 139746805892992 estimator.py:1984] Estimator's model_fn (<function model_fn_builder.<locals>.model_fn at 0x7f190a1efb70>) includes params argument, but params are not passed to Estimator.
# W0620 14:05:41.052392 139746805892992 estimator.py:1811] Using temporary folder as model directory: /tmp/tmp8oxmnxt3
# W0620 14:05:42.509199 139746805892992 estimator.py:1984] Estimator's model_fn (<function model_fn_builder.<locals>.model_fn at 0x7f190a1efb70>) includes params argument, but params are not passed to Estimator.
# W0620 14:05:42.572685 139746805892992 estimator.py:1811] Using temporary folder as model directory: /tmp/tmp4t4lxclc
# W0620 14:05:43.426898 139746805892992 estimator.py:1984] Estimator's model_fn (<function model_fn_builder.<locals>.model_fn at 0x7f190a1efb70>) includes params argument, but params are not passed to Estimator.
# W0620 14:05:43.476274 139746805892992 estimator.py:1811] Using temporary folder as model directory: /tmp/tmpw1h6r_2h
# W0620 14:05:43.833844 139746805892992 estimator.py:1984] Estimator's model_fn (<function model_fn_builder.<locals>.model_fn at 0x7f190a1efb70>) includes params argument, but params are not passed to Estimator.
# W0620 14:05:43.902640 139746805892992 estimator.py:1811] Using temporary folder as model directory: /tmp/tmpj54x_jnw
# W0620 14:05:47.689792 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:171: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0620 14:05:47.801432 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:409: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# W0620 14:05:49.203798 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:490: The name tf.assert_less_equal is deprecated. Please use tf.compat.v1.assert_less_equal instead.
#
# W0620 14:05:51.466439 139746805892992 deprecation.py:323] From /tmp/BERT_keras/google_bert/modeling.py:671: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# W0620 14:05:56.453134 139746805892992 estimator.py:1984] Estimator's model_fn (<function model_fn_builder.<locals>.model_fn at 0x7f190a1efb70>) includes params argument, but params are not passed to Estimator.
# W0620 14:05:56.517263 139746805892992 estimator.py:1811] Using temporary folder as model directory: /tmp/tmpqcyhi86f
# W0620 14:05:59.220115 139746805892992 estimator.py:1984] Estimator's model_fn (<function model_fn_builder.<locals>.model_fn at 0x7f190a1efb70>) includes params argument, but params are not passed to Estimator.
# W0620 14:05:59.279594 139746805892992 estimator.py:1811] Using temporary folder as model directory: /tmp/tmpyo0z59g4
# W0620 14:06:05.156430 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:171: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0620 14:06:05.270309 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:409: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# W0620 14:06:06.369131 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:490: The name tf.assert_less_equal is deprecated. Please use tf.compat.v1.assert_less_equal instead.
#
# W0620 14:06:06.820448 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:171: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0620 14:06:06.934716 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:409: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# W0620 14:06:08.133009 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:490: The name tf.assert_less_equal is deprecated. Please use tf.compat.v1.assert_less_equal instead.
#
# W0620 14:06:08.373918 139746805892992 deprecation.py:323] From /tmp/BERT_keras/google_bert/modeling.py:671: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# W0620 14:06:09.899517 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:171: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0620 14:06:09.981494 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:409: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# W0620 14:06:10.071220 139746805892992 deprecation.py:323] From /tmp/BERT_keras/google_bert/modeling.py:671: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# W0620 14:06:11.235652 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:490: The name tf.assert_less_equal is deprecated. Please use tf.compat.v1.assert_less_equal instead.
#
# W0620 14:06:13.118218 139746805892992 deprecation.py:323] From /tmp/BERT_keras/google_bert/modeling.py:671: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# W0620 14:06:25.282295 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:171: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0620 14:06:25.419066 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:409: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# W0620 14:06:26.577380 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:490: The name tf.assert_less_equal is deprecated. Please use tf.compat.v1.assert_less_equal instead.
#
# W0620 14:06:28.411580 139746805892992 deprecation.py:323] From /tmp/BERT_keras/google_bert/modeling.py:671: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# W0620 14:06:32.231674 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:171: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0620 14:06:32.327251 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:409: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# W0620 14:06:33.370780 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:490: The name tf.assert_less_equal is deprecated. Please use tf.compat.v1.assert_less_equal instead.
#
# W0620 14:06:33.839204 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:171: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0620 14:06:33.956102 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:409: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# W0620 14:06:35.024552 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:490: The name tf.assert_less_equal is deprecated. Please use tf.compat.v1.assert_less_equal instead.
#
# W0620 14:06:35.308158 139746805892992 deprecation.py:323] From /tmp/BERT_keras/google_bert/modeling.py:671: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# W0620 14:06:36.685506 139746805892992 deprecation.py:323] From /tmp/BERT_keras/google_bert/modeling.py:671: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# W0620 14:06:40.777819 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:171: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0620 14:06:40.807402 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:171: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0620 14:06:40.882488 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:409: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# W0620 14:06:40.905180 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:409: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# W0620 14:06:41.926912 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:490: The name tf.assert_less_equal is deprecated. Please use tf.compat.v1.assert_less_equal instead.
# W0620 14:06:41.947404 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:490: The name tf.assert_less_equal is deprecated. Please use tf.compat.v1.assert_less_equal instead.
#
#
# W0620 14:06:43.441690 139746805892992 deprecation.py:323] From /tmp/BERT_keras/google_bert/modeling.py:671: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.W0620 14:06:43.456356 139746805892992 deprecation.py:323] From /tmp/BERT_keras/google_bert/modeling.py:671: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
#
# W0620 14:06:50.044664 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:171: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0620 14:06:50.140664 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:409: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# W0620 14:06:51.356008 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:490: The name tf.assert_less_equal is deprecated. Please use tf.compat.v1.assert_less_equal instead.
#
# W0620 14:06:53.015159 139746805892992 deprecation.py:323] From /tmp/BERT_keras/google_bert/modeling.py:671: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# W0620 14:06:55.459059 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:171: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0620 14:06:55.602523 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:409: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# W0620 14:06:57.012858 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:490: The name tf.assert_less_equal is deprecated. Please use tf.compat.v1.assert_less_equal instead.
#
# W0620 14:06:58.379766 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:171: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0620 14:06:58.504205 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:409: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# W0620 14:06:58.778073 139746805892992 deprecation.py:323] From /tmp/BERT_keras/google_bert/modeling.py:671: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# W0620 14:06:59.451650 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:490: The name tf.assert_less_equal is deprecated. Please use tf.compat.v1.assert_less_equal instead.
#
# W0620 14:07:00.835949 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:171: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0620 14:07:00.936301 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:409: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
# W0620 14:07:00.966265 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:171: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
#
# W0620 14:07:00.993910 139746805892992 deprecation.py:323] From /tmp/BERT_keras/google_bert/modeling.py:671: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# W0620 14:07:01.068085 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:409: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# W0620 14:07:01.962562 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:490: The name tf.assert_less_equal is deprecated. Please use tf.compat.v1.assert_less_equal instead.
#
# W0620 14:07:02.190551 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:490: The name tf.assert_less_equal is deprecated. Please use tf.compat.v1.assert_less_equal instead.
#
# W0620 14:07:03.550541 139746805892992 deprecation.py:323] From /tmp/BERT_keras/google_bert/modeling.py:671: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# W0620 14:07:03.834153 139746805892992 deprecation.py:323] From /tmp/BERT_keras/google_bert/modeling.py:671: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# W0620 14:07:07.846239 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:171: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0620 14:07:07.971580 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:409: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# W0620 14:07:08.925082 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:490: The name tf.assert_less_equal is deprecated. Please use tf.compat.v1.assert_less_equal instead.
#
# W0620 14:07:09.579104 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:171: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0620 14:07:09.663528 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:409: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# W0620 14:07:10.491192 139746805892992 deprecation.py:323] From /tmp/BERT_keras/google_bert/modeling.py:671: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# W0620 14:07:10.630160 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:490: The name tf.assert_less_equal is deprecated. Please use tf.compat.v1.assert_less_equal instead.
#
# W0620 14:07:12.381932 139746805892992 deprecation.py:323] From /tmp/BERT_keras/google_bert/modeling.py:671: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# W0620 14:07:15.732175 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:171: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0620 14:07:15.842375 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:409: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# W0620 14:07:16.929164 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:490: The name tf.assert_less_equal is deprecated. Please use tf.compat.v1.assert_less_equal instead.
#
# W0620 14:07:18.772168 139746805892992 deprecation.py:323] From /tmp/BERT_keras/google_bert/modeling.py:671: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# W0620 14:07:44.734134 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:171: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0620 14:07:44.842501 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:409: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# W0620 14:07:45.994768 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:490: The name tf.assert_less_equal is deprecated. Please use tf.compat.v1.assert_less_equal instead.
#
# W0620 14:07:46.063979 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:171: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0620 14:07:46.219962 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:409: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# W0620 14:07:47.196741 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:490: The name tf.assert_less_equal is deprecated. Please use tf.compat.v1.assert_less_equal instead.
#
# W0620 14:07:47.678707 139746805892992 deprecation.py:323] From /tmp/BERT_keras/google_bert/modeling.py:671: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# W0620 14:07:48.915745 139746805892992 deprecation.py:323] From /tmp/BERT_keras/google_bert/modeling.py:671: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# W0620 14:07:51.117009 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:171: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0620 14:07:51.233034 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:409: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# W0620 14:07:52.240181 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:490: The name tf.assert_less_equal is deprecated. Please use tf.compat.v1.assert_less_equal instead.
#
# W0620 14:07:53.958712 139746805892992 deprecation.py:323] From /tmp/BERT_keras/google_bert/modeling.py:671: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# W0620 14:08:02.421246 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:171: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0620 14:08:02.652185 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:409: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# W0620 14:08:03.757272 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:490: The name tf.assert_less_equal is deprecated. Please use tf.compat.v1.assert_less_equal instead.
#
# W0620 14:08:05.455879 139746805892992 deprecation.py:323] From /tmp/BERT_keras/google_bert/modeling.py:671: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# W0620 14:08:19.150808 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:171: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0620 14:08:19.281409 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:409: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# W0620 14:08:20.377032 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:490: The name tf.assert_less_equal is deprecated. Please use tf.compat.v1.assert_less_equal instead.
#
# W0620 14:08:25.308950 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:171: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0620 14:08:25.420942 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:409: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# W0620 14:08:29.980382 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:171: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0620 14:08:30.133938 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:409: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# W0620 14:08:31.050839 139746805892992 deprecation.py:323] From /tmp/BERT_keras/google_bert/modeling.py:671: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# W0620 14:08:35.233225 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:490: The name tf.assert_less_equal is deprecated. Please use tf.compat.v1.assert_less_equal instead.
#
# W0620 14:08:36.839911 139746805892992 deprecation.py:323] From /tmp/BERT_keras/google_bert/modeling.py:671: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# W0620 14:08:39.217836 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:490: The name tf.assert_less_equal is deprecated. Please use tf.compat.v1.assert_less_equal instead.
#
# W0620 14:08:40.706659 139746805892992 deprecation.py:323] From /tmp/BERT_keras/google_bert/modeling.py:671: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# W0620 14:09:00.120070 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:193: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# W0620 14:09:02.342387 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:201: The name tf.train.init_from_checkpoint is deprecated. Please use tf.compat.v1.train.init_from_checkpoint instead.
#
# W0620 14:09:13.357032 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:193: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# W0620 14:09:16.862401 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:193: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# W0620 14:09:17.307215 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:193: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# W0620 14:09:18.908905 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:201: The name tf.train.init_from_checkpoint is deprecated. Please use tf.compat.v1.train.init_from_checkpoint instead.
#
# W0620 14:09:19.339634 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:201: The name tf.train.init_from_checkpoint is deprecated. Please use tf.compat.v1.train.init_from_checkpoint instead.
#
# W0620 14:09:23.387103 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:201: The name tf.train.init_from_checkpoint is deprecated. Please use tf.compat.v1.train.init_from_checkpoint instead.
#
# W0620 14:09:27.182143 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:193: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# W0620 14:09:29.268873 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:201: The name tf.train.init_from_checkpoint is deprecated. Please use tf.compat.v1.train.init_from_checkpoint instead.
#
# W0620 14:09:39.764345 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:193: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# W0620 14:09:41.158768 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:193: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# W0620 14:09:41.834523 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:201: The name tf.train.init_from_checkpoint is deprecated. Please use tf.compat.v1.train.init_from_checkpoint instead.
#
# W0620 14:09:43.209408 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:201: The name tf.train.init_from_checkpoint is deprecated. Please use tf.compat.v1.train.init_from_checkpoint instead.
#
# W0620 14:09:46.438364 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:193: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# W0620 14:09:47.258495 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:193: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# W0620 14:09:48.609773 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:201: The name tf.train.init_from_checkpoint is deprecated. Please use tf.compat.v1.train.init_from_checkpoint instead.
#
# W0620 14:09:49.079899 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:201: The name tf.train.init_from_checkpoint is deprecated. Please use tf.compat.v1.train.init_from_checkpoint instead.
#
# W0620 14:09:55.095145 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:202: The name tf.train.Scaffold is deprecated. Please use tf.compat.v1.train.Scaffold instead.
#
# W0620 14:09:55.859393 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:193: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# W0620 14:09:57.966037 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:201: The name tf.train.init_from_checkpoint is deprecated. Please use tf.compat.v1.train.init_from_checkpoint instead.
#
# W0620 14:10:00.443436 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:193: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# W0620 14:10:00.626845 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:193: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# W0620 14:10:02.495891 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:202: The name tf.train.Scaffold is deprecated. Please use tf.compat.v1.train.Scaffold instead.
#
# W0620 14:10:02.765801 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:201: The name tf.train.init_from_checkpoint is deprecated. Please use tf.compat.v1.train.init_from_checkpoint instead.
#
# W0620 14:10:02.795075 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:201: The name tf.train.init_from_checkpoint is deprecated. Please use tf.compat.v1.train.init_from_checkpoint instead.
#
# W0620 14:10:03.701439 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:202: The name tf.train.Scaffold is deprecated. Please use tf.compat.v1.train.Scaffold instead.
#
# W0620 14:10:07.163607 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:193: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# W0620 14:10:09.217257 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:193: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# W0620 14:10:09.415798 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:201: The name tf.train.init_from_checkpoint is deprecated. Please use tf.compat.v1.train.init_from_checkpoint instead.
#
# W0620 14:10:09.570760 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:202: The name tf.train.Scaffold is deprecated. Please use tf.compat.v1.train.Scaffold instead.
#
# W0620 14:10:11.398007 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:201: The name tf.train.init_from_checkpoint is deprecated. Please use tf.compat.v1.train.init_from_checkpoint instead.
#
# W0620 14:10:12.799929 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:193: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# W0620 14:10:13.094097 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:202: The name tf.train.Scaffold is deprecated. Please use tf.compat.v1.train.Scaffold instead.
#
# W0620 14:10:14.769739 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:193: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# W0620 14:10:15.076591 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:201: The name tf.train.init_from_checkpoint is deprecated. Please use tf.compat.v1.train.init_from_checkpoint instead.
#
# W0620 14:10:16.939561 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:201: The name tf.train.init_from_checkpoint is deprecated. Please use tf.compat.v1.train.init_from_checkpoint instead.
#
# W0620 14:10:23.430861 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:193: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# W0620 14:10:25.757642 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:201: The name tf.train.init_from_checkpoint is deprecated. Please use tf.compat.v1.train.init_from_checkpoint instead.
#
# W0620 14:10:27.799222 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:202: The name tf.train.Scaffold is deprecated. Please use tf.compat.v1.train.Scaffold instead.
#
# W0620 14:10:28.078874 139746805892992 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/array_ops.py:1354: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0620 14:10:28.572603 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:202: The name tf.train.Scaffold is deprecated. Please use tf.compat.v1.train.Scaffold instead.
#
# W0620 14:10:30.031124 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:171: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0620 14:10:30.158264 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:409: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# W0620 14:10:31.253739 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:490: The name tf.assert_less_equal is deprecated. Please use tf.compat.v1.assert_less_equal instead.
#
# ...
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0620 14:11:35.311900 139746805892992 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/array_ops.py:1354: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0620 14:11:36.114399 139746805892992 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/array_ops.py:1354: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0620 14:11:40.682975 139746805892992 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/array_ops.py:1354: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0620 14:11:41.498971 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:171: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0620 14:11:41.618435 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:409: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# W0620 14:11:42.561976 139746805892992 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/array_ops.py:1354: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0620 14:11:42.585495 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:490: The name tf.assert_less_equal is deprecated. Please use tf.compat.v1.assert_less_equal instead.
#
# W0620 14:11:43.899757 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:202: The name tf.train.Scaffold is deprecated. Please use tf.compat.v1.train.Scaffold instead.
#
# W0620 14:11:44.125232 139746805892992 deprecation.py:323] From /tmp/BERT_keras/google_bert/modeling.py:671: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# W0620 14:11:44.646683 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:193: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# W0620 14:11:46.853374 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:201: The name tf.train.init_from_checkpoint is deprecated. Please use tf.compat.v1.train.init_from_checkpoint instead.
#
# W0620 14:11:48.887385 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:202: The name tf.train.Scaffold is deprecated. Please use tf.compat.v1.train.Scaffold instead.
#
# W0620 14:11:53.590703 139746805892992 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/array_ops.py:1354: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0620 14:11:54.040881 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:193: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# W0620 14:11:54.655952 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:193: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# W0620 14:11:55.810961 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:201: The name tf.train.init_from_checkpoint is deprecated. Please use tf.compat.v1.train.init_from_checkpoint instead.
#
# W0620 14:11:56.407934 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:201: The name tf.train.init_from_checkpoint is deprecated. Please use tf.compat.v1.train.init_from_checkpoint instead.
#
# W0620 14:11:58.848471 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:202: The name tf.train.Scaffold is deprecated. Please use tf.compat.v1.train.Scaffold instead.
#
# W0620 14:12:03.081429 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:171: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0620 14:12:03.184653 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:409: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# W0620 14:12:03.976979 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/modeling.py:490: The name tf.assert_less_equal is deprecated. Please use tf.compat.v1.assert_less_equal instead.
#
# W0620 14:12:05.600447 139746805892992 deprecation.py:323] From /tmp/BERT_keras/google_bert/modeling.py:671: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# W0620 14:12:07.744696 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:202: The name tf.train.Scaffold is deprecated. Please use tf.compat.v1.train.Scaffold instead.
#
# W0620 14:12:13.090085 139746805892992 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/tpu/tpu_estimator.py:808: Variable.load (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Prefer Variable.assign which has equivalent behavior in 2.X.
# W0620 14:12:13.474169 139746805892992 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/array_ops.py:1354: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0620 14:12:17.614228 139746805892992 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/array_ops.py:1354: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0620 14:12:21.907724 139746805892992 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/array_ops.py:1354: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0620 14:12:24.902599 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:202: The name tf.train.Scaffold is deprecated. Please use tf.compat.v1.train.Scaffold instead.
#
# W0620 14:12:28.143755 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:202: The name tf.train.Scaffold is deprecated. Please use tf.compat.v1.train.Scaffold instead.
#
# W0620 14:12:28.384799 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:202: The name tf.train.Scaffold is deprecated. Please use tf.compat.v1.train.Scaffold instead.
# W0620 14:12:28.388414 139746805892992 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/array_ops.py:1354: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
#
# W0620 14:12:44.029469 139746805892992 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/array_ops.py:1354: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0620 14:12:45.254780 139746805892992 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/array_ops.py:1354: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0620 14:12:45.918091 139746805892992 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/array_ops.py:1354: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0620 14:13:03.109201 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:193: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# W0620 14:13:04.187245 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:201: The name tf.train.init_from_checkpoint is deprecated. Please use tf.compat.v1.train.init_from_checkpoint instead.
#
# W0620 14:13:06.332796 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:193: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# W0620 14:13:07.368011 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:201: The name tf.train.init_from_checkpoint is deprecated. Please use tf.compat.v1.train.init_from_checkpoint instead.
#
# W0620 14:13:10.528532 139746805892992 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/tpu/tpu_estimator.py:808: Variable.load (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Prefer Variable.assign which has equivalent behavior in 2.X.
# W0620 14:13:10.698787 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:193: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# W0620 14:13:11.274267 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:193: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# W0620 14:13:11.618988 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:201: The name tf.train.init_from_checkpoint is deprecated. Please use tf.compat.v1.train.init_from_checkpoint instead.
#
# W0620 14:13:12.157969 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:201: The name tf.train.init_from_checkpoint is deprecated. Please use tf.compat.v1.train.init_from_checkpoint instead.
#
# W0620 14:13:17.548391 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:202: The name tf.train.Scaffold is deprecated. Please use tf.compat.v1.train.Scaffold instead.
#
# W0620 14:13:20.965414 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:202: The name tf.train.Scaffold is deprecated. Please use tf.compat.v1.train.Scaffold instead.
#
# W0620 14:13:21.092382 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:193: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# W0620 14:13:21.959086 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:201: The name tf.train.init_from_checkpoint is deprecated. Please use tf.compat.v1.train.init_from_checkpoint instead.
#
# W0620 14:13:25.379967 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:202: The name tf.train.Scaffold is deprecated. Please use tf.compat.v1.train.Scaffold instead.
#
# W0620 14:13:25.909103 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:202: The name tf.train.Scaffold is deprecated. Please use tf.compat.v1.train.Scaffold instead.
#
# W0620 14:13:30.588443 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:193: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# W0620 14:13:31.458101 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:201: The name tf.train.init_from_checkpoint is deprecated. Please use tf.compat.v1.train.init_from_checkpoint instead.
#
# W0620 14:13:33.287299 139746805892992 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/array_ops.py:1354: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0620 14:13:34.369834 139746805892992 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/array_ops.py:1354: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0620 14:13:37.540867 139746805892992 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/array_ops.py:1354: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0620 14:13:37.933300 139746805892992 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/array_ops.py:1354: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0620 14:13:43.863779 139746805892992 deprecation_wrapper.py:119] From /tmp/BERT_keras/google_bert/extract_features.py:202: The name tf.train.Scaffold is deprecated. Please use tf.compat.v1.train.Scaffold instead.
#
# W0620 14:13:46.077906 139746805892992 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/array_ops.py:1354: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0620 14:14:13.945499 139746805892992 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/tpu/tpu_estimator.py:808: Variable.load (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Prefer Variable.assign which has equivalent behavior in 2.X.

# %%
import pickle

with open('/tmp/pkl_X.pkl', 'wb') as f:
  pickle.dump(X, f)
# !gsutil cp /tmp/pkl_X.pkl gs://module-4-project/pkl_X.pkl

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# !gsutil cp gs://module-4-project/pkl_X.pkl /tmp/pkl_X.pkl
with open('/tmp/pkl_X.pkl', 'rb') as f:
  X = pickle.load(f)

X_extracted=[]
for i, x in enumerate(X[0].items()):
  X_extracted.append(x[1])
X_extracted
# Out:
# Copying gs://module-4-project/pkl_X.pkl...
# / [1 files][    5.0 B/    5.0 B]
# Operation completed over 1 objects/5.0 B.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-ca8294c38435> in <module>()
#       4
#       5 X_extracted=[]
# ----> 6 for i, x in enumerate(X[0].items()):
#       7   X_extracted.append(x[1])
#       8 X_extracted
#
# TypeError: 'int' object is not subscriptable

# %%
rfc = RandomForestClassifier()
rfc.fit(X_extracted, marvel['label'])

# %%
x_predict = get_features('The hero is cool')

# %%
X_predict_extracted=[]
for i, x in enumerate(x_predict.items()):
  X_predict_extracted.append(x[1])
X_predict_extracted

# %%
rfc.predict(X_predict_extracted)
